# %%
import pandas as pd
from scipy import stats
import numpy as np

# %%
drought_df = pd.read_csv("Drought/drought_2014-2015.csv")

# %%
drought_df
# Out:
#       drought_id          County State  None   D0   D1     D2      D3     D4  \
# 0              0  Alameda County    CA   0.0  0.0  0.0    0.0   81.04  18.96
# 1              1  Alameda County    CA   0.0  0.0  0.0    0.0   81.04  18.96
# 2              2  Alameda County    CA   0.0  0.0  0.0    0.0   81.04  18.96
# 3              3  Alameda County    CA   0.0  0.0  0.0    0.0   81.04  18.96
# 4              4  Alameda County    CA   0.0  0.0  0.0    0.0   81.04  18.96
# ...          ...             ...   ...   ...  ...  ...    ...     ...    ...
# 6027       17997     Yuba County    CA   0.0  0.0  0.0    0.0  100.00   0.00
# 6028       17998     Yuba County    CA   0.0  0.0  0.0    0.0  100.00   0.00
# 6029       17999     Yuba County    CA   0.0  0.0  0.0    0.0  100.00   0.00
# 6030       18000     Yuba County    CA   0.0  0.0  0.0    0.0  100.00   0.00
# 6031       18001     Yuba County    CA   0.0  0.0  0.0  100.0    0.00   0.00
#
#      ValidStart  ValidEnd  Year
# ...

# %%
average_df = drought_df.groupby(["Year", "County"]).mean()

# %%
year_count_df = average_df.reset_index()

# %%
year_count_df.to_csv("Drought/year_county_averages.csv")

# %%
# importing dependencies
import pandas as pd
import pathlib
import datetime

filepath = "CA_Fires_2014-2015.csv"

# reading drought CSV into dataframe
fires_df = pd.read_csv(filepath)
fires_df

# %%
fires_df.dtypes
# Out:
# Unnamed: 0            int64
# Unnamed: 0.1          int64
# FIRE_YEAR             int64
# DISCOVERY_DATE      float64
# DISCOVERY_DOY         int64
# DISCOVERY_TIME      float64
# STAT_CAUSE_DESCR     object
# CONT_DATE           float64
# CONT_DOY            float64
# LATITUDE            float64
# LONGITUDE           float64
# STATE                object
# COUNTY               object
# LAT_LONG             object
# COUNTY_NAME          object
# dtype: object

# %%
fires_df.columns
# Out:
# Index(['Unnamed: 0', 'Unnamed: 0.1', 'FIRE_YEAR', 'DISCOVERY_DATE',
#        'DISCOVERY_DOY', 'DISCOVERY_TIME', 'STAT_CAUSE_DESCR', 'CONT_DATE',
#        'CONT_DOY', 'LATITUDE', 'LONGITUDE', 'STATE', 'COUNTY', 'LAT_LONG',
#        'COUNTY_NAME'],
#       dtype='object')

# %%
fires_df.drop(columns=["DISCOVERY_DATE", "Unnamed: 0", "CONT_DATE", "CONT_DOY"], inplace=True)

# %%
fires_df.rename(columns={"Unnamed: 0.1":"FIRE_ID"}, inplace=True)
fires_df
# Out:
#        FIRE_ID  FIRE_YEAR  DISCOVERY_DOY  DISCOVERY_TIME   STAT_CAUSE_DESCR  \
# 0      1722209       2014            160          1105.0           Campfire
# 1      1722210       2014            203          1620.0          Lightning
# 2      1722211       2014            192          1630.0          Lightning
# 3      1722212       2014            192          1300.0          Lightning
# 4      1722213       2014            194          1530.0          Lightning
# ...        ...        ...            ...             ...                ...
# 13854  1880460       2015            269          1726.0  Missing/Undefined
# 13855  1880461       2015            278           126.0      Miscellaneous
# 13856  1880462       2015            122          2052.0  Missing/Undefined
# 13857  1880463       2015            287          2309.0  Missing/Undefined
# 13858  1880464       2015             73          2128.0      Miscellaneous
#
# ...

# %%
fires_df["DISCOVERY_DATE"] = ""
fires_df
# Out:
#        FIRE_ID  FIRE_YEAR  DISCOVERY_DOY  DISCOVERY_TIME   STAT_CAUSE_DESCR  \
# 0      1722209       2014            160          1105.0           Campfire
# 1      1722210       2014            203          1620.0          Lightning
# 2      1722211       2014            192          1630.0          Lightning
# 3      1722212       2014            192          1300.0          Lightning
# 4      1722213       2014            194          1530.0          Lightning
# ...        ...        ...            ...             ...                ...
# 13854  1880460       2015            269          1726.0  Missing/Undefined
# 13855  1880461       2015            278           126.0      Miscellaneous
# 13856  1880462       2015            122          2052.0  Missing/Undefined
# 13857  1880463       2015            287          2309.0  Missing/Undefined
# 13858  1880464       2015             73          2128.0      Miscellaneous
#
# ...

# %%
# converting DOY to date
discovery_date = []

for x in range(0, len(fires_df)):
    YEAR = fires_df['FIRE_YEAR'][x]
    DAY_OF_YEAR = fires_df['DISCOVERY_DOY'][x]
    d = datetime.date(YEAR, 1, 1) + datetime.timedelta(int(DAY_OF_YEAR - 1))
    fires_df['DISCOVERY_DATE'][x] = d
# Out:
# <ipython-input-11-fd696ed956d1>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   fires_df['DISCOVERY_DATE'][x] = d

# %%
fires_df
# Out:
#        FIRE_ID  FIRE_YEAR  DISCOVERY_DOY  DISCOVERY_TIME   STAT_CAUSE_DESCR  \
# 0      1722209       2014            160          1105.0           Campfire
# 1      1722210       2014            203          1620.0          Lightning
# 2      1722211       2014            192          1630.0          Lightning
# 3      1722212       2014            192          1300.0          Lightning
# 4      1722213       2014            194          1530.0          Lightning
# ...        ...        ...            ...             ...                ...
# 13854  1880460       2015            269          1726.0  Missing/Undefined
# 13855  1880461       2015            278           126.0      Miscellaneous
# 13856  1880462       2015            122          2052.0  Missing/Undefined
# 13857  1880463       2015            287          2309.0  Missing/Undefined
# 13858  1880464       2015             73          2128.0      Miscellaneous
#
# ...

# %%
fires_df.drop(columns=["DISCOVERY_DOY", "DISCOVERY_TIME"], inplace=True)

# %%
fires_df.dtypes
# Out:
# FIRE_ID               int64
# FIRE_YEAR             int64
# STAT_CAUSE_DESCR     object
# LATITUDE            float64
# LONGITUDE           float64
# STATE                object
# COUNTY               object
# LAT_LONG             object
# COUNTY_NAME          object
# DISCOVERY_DATE       object
# dtype: object

# %%
fires_df.to_csv("2014-15-CA-FIRES.csv")

# %%
filepath_2 = "drought_2014-2015.csv"

# reading drought CSV into dataframe
drought_df = pd.read_csv(filepath_2)
drought_df
# Out:
#       Unnamed: 0          County State  None   D0   D1     D2      D3     D4  \
# 0              0  Alameda County    CA   0.0  0.0  0.0    0.0   81.04  18.96
# 1              1  Alameda County    CA   0.0  0.0  0.0    0.0   81.04  18.96
# 2              2  Alameda County    CA   0.0  0.0  0.0    0.0   81.04  18.96
# 3              3  Alameda County    CA   0.0  0.0  0.0    0.0   81.04  18.96
# 4              4  Alameda County    CA   0.0  0.0  0.0    0.0   81.04  18.96
# ...          ...             ...   ...   ...  ...  ...    ...     ...    ...
# 6027       17997     Yuba County    CA   0.0  0.0  0.0    0.0  100.00   0.00
# 6028       17998     Yuba County    CA   0.0  0.0  0.0    0.0  100.00   0.00
# 6029       17999     Yuba County    CA   0.0  0.0  0.0    0.0  100.00   0.00
# 6030       18000     Yuba County    CA   0.0  0.0  0.0    0.0  100.00   0.00
# 6031       18001     Yuba County    CA   0.0  0.0  0.0  100.0    0.00   0.00
#
#       ValidStart    ValidEnd  Year
# ...

# %%
drought_df.dtypes
# Out:
# Unnamed: 0      int64
# County         object
# State          object
# None          float64
# D0            float64
# D1            float64
# D2            float64
# D3            float64
# D4            float64
# ValidStart     object
# ValidEnd       object
# Year            int64
# dtype: object
